# %%
# importing the required module 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Optional for disabling warnings 

import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Import the excel file containing exam scores and describe it

df = pd.read_excel (r'./Fall 23 Physio Class Entire (5).xlsx', index_col=0) 
df.describe()
# Out:
#            Exam1  Exam 1 changed     Exam_2  Exam 2 Curved out of 15
# count  58.000000       59.000000  59.000000                59.000000
# mean   26.862069       27.906780  19.536645                11.988340
# std     4.071502        5.340537   4.486163                 2.379100
# min    17.000000        1.500000   0.662069                 0.812069
# 25%    24.000000       25.000000  17.000000                10.750000
# 50%    27.000000       28.500000  19.000000                11.750000
# 75%    30.000000       31.500000  23.000000                13.750000
# max    37.000000       38.500000  27.000000                15.750000

# %%
df = df.dropna()
df.describe()
# Out:
#            Exam1  Exam 1 changed     Exam_2  Exam 2 Curved out of 15  \
# count  56.000000       56.000000  56.000000                56.000000
# mean   26.892857       28.392857  20.053571                12.276786
# std     4.101789        4.101789   3.670123                 1.835062
# min    17.000000       18.500000  11.000000                 7.750000
# 25%    24.000000       25.500000  18.000000                11.250000
# 50%    27.000000       28.500000  20.000000                12.250000
# 75%    30.000000       31.500000  23.000000                13.750000
# max    37.000000       38.500000  27.000000                15.750000
#
#         Exam2new  Exam2curved
# count  56.000000    56.000000
# mean    0.668452     0.818452
# std     0.122337     0.122337
# min     0.366667     0.516667
# 25%     0.600000     0.750000
# 50%     0.666667     0.816667
# 75%     0.766667     0.916667
# max     0.900000     1.050000

# %%
#Add a column called "Exam_percent" that is the Exam 1 column * the total # of questions

df['Exam2new'] = df.Exam_2/30 #adjustment for review
df.describe()
# Out:
#            Exam1  Exam 1 changed     Exam_2  Exam 2 Curved out of 15  \
# count  56.000000       56.000000  56.000000                56.000000
# mean   26.892857       28.392857  20.053571                12.276786
# std     4.101789        4.101789   3.670123                 1.835062
# min    17.000000       18.500000  11.000000                 7.750000
# 25%    24.000000       25.500000  18.000000                11.250000
# 50%    27.000000       28.500000  20.000000                12.250000
# 75%    30.000000       31.500000  23.000000                13.750000
# max    37.000000       38.500000  27.000000                15.750000
#
#         Exam2new  Exam2curved
# count  56.000000    56.000000
# mean    0.668452     0.818452
# std     0.122337     0.122337
# min     0.366667     0.516667
# 25%     0.600000     0.750000
# 50%     0.666667     0.816667
# 75%     0.766667     0.916667
# max     0.900000     1.050000

# %%
#Add a column called "Exam_percent" that is the Exam 1 column * the total # of questions

df['Exam2curved'] = df.Exam2new+0.15 #adjustment for review
df.describe()
# Out:
#            Exam1  Exam 1 changed     Exam_2  Exam 2 Curved out of 15  \
# count  56.000000       56.000000  56.000000                56.000000
# mean   26.892857       28.392857  20.053571                12.276786
# std     4.101789        4.101789   3.670123                 1.835062
# min    17.000000       18.500000  11.000000                 7.750000
# 25%    24.000000       25.500000  18.000000                11.250000
# 50%    27.000000       28.500000  20.000000                12.250000
# 75%    30.000000       31.500000  23.000000                13.750000
# max    37.000000       38.500000  27.000000                15.750000
#
#         Exam2new  Exam2curved
# count  56.000000    56.000000
# mean    0.668452     0.818452
# std     0.122337     0.122337
# min     0.366667     0.516667
# 25%     0.600000     0.750000
# 50%     0.666667     0.816667
# 75%     0.766667     0.916667
# max     0.900000     1.050000

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x1 = df.Exam2new*100
plt.hist(x1, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Original Score', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,100)

plt.axvline(x1.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()))
# Out:
# Text(73.52976190476191, 8.504999999999999, 'Mean: 66.85')

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x2 = df.Exam2curved*100
plt.hist(x2, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Curved Score', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,110)

plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))
# Out:
# Text(90.0297619047619, 8.504999999999999, 'Mean: 81.85')

# %%
kwargs = dict(hist_kws={'alpha':.4}, kde_kws={'linewidth':3})

plt.figure(figsize=(10,7), dpi= 300)
sns.distplot(x1, bins = 25, color="dodgerblue", label="Original", **kwargs)
plt.axvline(x1.mean(), color='dodgerblue', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*.75, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()), color="dodgerblue")

sns.distplot(x2, bins = 25, color="orange", label="Curved", **kwargs)
plt.axvline(x2.mean(), color='orange', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.10, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()), color="orange")
plt.xlim(20,110)
plt.legend();
plt.gca().set(title='Fall 2022 Human Physiology - Exam 2 Scores - Before and After Curve', ylabel='Density', xlabel='Score (%)')
# Out:
# [Text(0.5, 1.0, 'Fall 2022 Human Physiology - Exam 2 Scores - Before and After Curve'),
#  Text(0, 0.5, 'Density'),
#  Text(0.5, 0, 'Score (%)')]
