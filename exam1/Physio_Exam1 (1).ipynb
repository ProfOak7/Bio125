# %%
# importing the required module 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Optional for disabling warnings 

import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Import the excel file containing exam scores and describe it

df = pd.read_excel (r'./Fall 23 Physio Class Entire (1).xlsx', index_col=0) 
df.describe()
# Out:
#            Exam1
# count  57.000000
# mean   26.824561
# std     4.097572
# min    17.000000
# 25%    24.000000
# 50%    27.000000
# 75%    30.000000
# max    37.000000

# %%
#Add a column called "Exam_percent" that is the Exam 1 column * the total # of questions

df['Exam_percent'] = df.Exam1/38
df.describe()
# Out:
#            Exam1  Exam_percent
# count  57.000000     57.000000
# mean   26.824561      0.705910
# std     4.097572      0.107831
# min    17.000000      0.447368
# 25%    24.000000      0.631579
# 50%    27.000000      0.710526
# 75%    30.000000      0.789474
# max    37.000000      0.973684

# %%
#Add a column called "Exam_percent" that is the Exam 1 % + 4.4%.

df['Exam_percent_curved'] = df.Exam1/38 + 0.044090
df.describe()
# Out:
#            Exam1  Exam_percent  Exam_percent_curved
# count  57.000000     57.000000            57.000000
# mean   26.824561      0.705910             0.750000
# std     4.097572      0.107831             0.107831
# min    17.000000      0.447368             0.491458
# 25%    24.000000      0.631579             0.675669
# 50%    27.000000      0.710526             0.754616
# 75%    30.000000      0.789474             0.833564
# max    37.000000      0.973684             1.017774

# %%
# Add a column that gives their their curved score out of 15 and describe it

df['Exam_curvedscore'] = df.Exam_percent_curved*15
df.describe()
# Out:
#            Exam1  Exam_percent  Exam_percent_curved  Exam_curvedscore
# count  57.000000     57.000000            57.000000         57.000000
# mean   26.824561      0.705910             0.750000         11.249993
# std     4.097572      0.107831             0.107831          1.617463
# min    17.000000      0.447368             0.491458          7.371876
# 25%    24.000000      0.631579             0.675669         10.135034
# 50%    27.000000      0.710526             0.754616         11.319245
# 75%    30.000000      0.789474             0.833564         12.503455
# max    37.000000      0.973684             1.017774         15.266613

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x1 = df.Exam_percent*100
plt.hist(x1, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Original Score', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,100)

plt.axvline(x1.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()))
# Out:
# Text(77.6500461680517, 7.5600000000000005, 'Mean: 70.59')

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x2 = df.Exam_percent_curved*100
plt.hist(x2, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Curved Score', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,102)

plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))
# Out:
# Text(82.49994616805172, 7.5600000000000005, 'Mean: 75.00')

# %%
kwargs = dict(hist_kws={'alpha':.4}, kde_kws={'linewidth':3})

plt.figure(figsize=(10,7), dpi= 300)
sns.distplot(x1, bins = 25, color="dodgerblue", label="Original", **kwargs)
plt.axvline(x1.mean(), color='dodgerblue', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*.75, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()), color="dodgerblue")

sns.distplot(x2, bins = 25, color="orange", label="Curved", **kwargs)
plt.axvline(x2.mean(), color='orange', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.10, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()), color="orange")
plt.xlim(20,110)
plt.legend();
plt.gca().set(title='Fall 2022 Human Anatomy - Exam 1 Scores - Before and After Curve', ylabel='Density', xlabel='Score (%)')
# Out:
# [Text(0.5, 1.0, 'Fall 2022 Human Anatomy - Exam 1 Scores - Before and After Curve'),
#  Text(0, 0.5, 'Density'),
#  Text(0.5, 0, 'Score (%)')]

# %%
# Plot Histogram on x
x1 = df.Exam_percent*15
plt.hist(x1, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Original Score - Out of 15', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,16)

plt.axvline(x1.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()))
# Out:
# Text(11.647506925207756, 7.5600000000000005, 'Mean: 10.59')

# %%
# Plot Histogram on x
x2 = df.Exam_percent_curved*15
plt.hist(x2, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Original Score - Out of 15', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,16)

plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))
# Out:
# Text(12.374991925207755, 7.5600000000000005, 'Mean: 11.25')

# %%
kwargs = dict(hist_kws={'alpha':.4}, kde_kws={'linewidth':3})

plt.figure(figsize=(10,7), dpi= 300)
sns.distplot(x1, bins = 25, color="dodgerblue", label="Original", **kwargs)
plt.axvline(x1.mean(), color='dodgerblue', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*.75, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()), color="dodgerblue")

sns.distplot(x2, bins = 25, color="orange", label="Curved", **kwargs)
plt.axvline(x2.mean(), color='orange', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.10, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()), color="orange")
plt.xlim(4,18)
plt.legend();
plt.gca().set(title='Fall 2022 Human Anatomy - Exam 1 Scores - Before and After Curve', ylabel='Density', xlabel='Score (%)')
# Out:
# [Text(0.5, 1.0, 'Fall 2022 Human Anatomy - Exam 1 Scores - Before and After Curve'),
#  Text(0, 0.5, 'Density'),
#  Text(0.5, 0, 'Score (%)')]
